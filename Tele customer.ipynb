# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customer=pd.read_csv("C:\\Users\\user\\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
customer.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
for col in customer.columns:
    print(col)
# Out:
# customerID
# gender
# SeniorCitizen
# Partner
# Dependents
# tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCharges
# Churn

# %%
customer.isnull().sum().sum()
# Out:
# 0

# %%
sns.lineplot(x="Partner",y="Contract",data=customer)
plt.show()

# %%
sns.pairplot(customer,hue="InternetService")
plt.show()

# %%
customer.drop(["customerID"],axis=1).head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
customer["gender"].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
customer["gender"].value_counts().keys()
# Out:
# Index(['Male', 'Female'], dtype='object')

# %%
plt.bar(list(customer["gender"].value_counts().keys()),list(customer["gender"].value_counts()))
plt.title("Customers acceptinng service by Gender")
plt.xlabel=("In thousands")
plt.ylabel=("Gender")
plt.show()

# %%
customer["SeniorCitizen"].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
customer["SeniorCitizen"].value_counts().keys()
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
customer["SeniorCitizen"].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(list(customer["SeniorCitizen"].value_counts()),labels=list(customer["SeniorCitizen"].value_counts().keys()),autopct="%0.1ff%%")
plt.show()

# %%
customer["Partner"].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
customer["Dependents"].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
customer["PhoneService"].value_counts()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
customer["InternetService"].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
customer["InternetService"].value_counts().keys()
# Out:
# Index(['Fiber optic', 'DSL', 'No'], dtype='object')

# %%
plt.bar(list(customer["InternetService"].value_counts().keys()),list(customer["InternetService"].value_counts()))
plt.title("InternetService")
plt.xlabel="Service Provided"
plt.ylabel="No. of customers"
plt.show()

# %%
customer["MultipleLines"].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
customer["MultipleLines"].value_counts().keys()
# Out:
# Index(['No', 'Yes', 'No phone service'], dtype='object')

# %%
plt.figure(figsize=(7,7))
plt.pie(list(customer["MultipleLines"].value_counts()),labels=list(customer["MultipleLines"].value_counts().keys()),autopct="%0.1ff%%")
plt.show()

# %%
customer.sort_values(by=["tenure"],ascending=False).head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes           Yes             DSL                  Yes  ...
# 193           Yes           Yes     Fiber optic                  Yes  ...
# 4553          Yes           Yes     Fiber optic                  Yes  ...
# 483           Yes           Yes     Fiber optic                   No  ...
# 3266          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
customer["OnlineSecurity"].value_counts()
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %%
customer["OnlineSecurity"].value_counts().keys()
# Out:
# Index(['No', 'Yes', 'No internet service'], dtype='object')

# %%
plt.figure(figsize=(7,7))
plt.pie(list(customer["OnlineSecurity"].value_counts()),labels=(customer["OnlineSecurity"].value_counts().keys()),autopct="%0.1ff%%")
plt.show()

# %%
customer["Contract"].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
customer["Contract"].value_counts().keys()
# Out:
# Index(['Month-to-month', 'Two year', 'One year'], dtype='object')

# %%
plt.bar(list(customer["Contract"].value_counts().keys()),list(customer["Contract"].value_counts()))
plt.show()

# %%
customer["PaperlessBilling"].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
customer["PaperlessBilling"].value_counts().keys()
# Out:
# Index(['Yes', 'No'], dtype='object')

# %%
plt.bar(list(customer["PaperlessBilling"].value_counts().keys()),list(customer["PaperlessBilling"].value_counts()))
plt.grid()
plt.show()

# %%
customer.sort_values(by=["MonthlyCharges"],ascending=False).head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4586  7569-NMZYQ  Female              0     Yes        Yes      72
# 2115  8984-HPEMB  Female              0      No         No      71
# 3894  5989-AXPUC  Female              0     Yes         No      68
# 4804  5734-EJKXG  Female              0      No         No      61
# 5127  8199-ZLLSA    Male              0      No         No      67
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4586          Yes           Yes     Fiber optic            Yes  ...
# 2115          Yes           Yes     Fiber optic            Yes  ...
# 3894          Yes           Yes     Fiber optic            Yes  ...
# 4804          Yes           Yes     Fiber optic            Yes  ...
# 5127          Yes           Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 4586              Yes         Yes         Yes             Yes  Two year
# ...

# %%
customer["DeviceProtection"].value_counts()
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
customer["DeviceProtection"].value_counts().keys()
# Out:
# Index(['No', 'Yes', 'No internet service'], dtype='object')

# %%
plt.pie(list(customer["DeviceProtection"].value_counts()),labels=list(customer["DeviceProtection"].value_counts().keys()),autopct="%0.1ff%%",radius=2)
plt.pie([1],colors="white",radius=1)
plt.show()

# %%
sns.barplot(x="Partner",y="tenure",data=customer)
plt.grid()
plt.show()

# %%
sns.scatterplot(x="MonthlyCharges",y="TotalCharges",data=customer)
plt.show()

# %%
sns.jointplot(x="MonthlyCharges",y="TotalCharges",data=customer)
plt.show()

# %%
sns.boxplot(x="Churn",y="MonthlyCharges",data=customer)
plt.show()

# %%
sns.boxplot(x="Churn",y="tenure",data=customer)
plt.show()

# %%
customer["StreamingMovies"].value_counts()
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %%
customer["StreamingMovies"].value_counts().keys()
# Out:
# Index(['No', 'Yes', 'No internet service'], dtype='object')

# %%
plt.bar(list(customer["StreamingMovies"].value_counts().keys()),list(customer["StreamingMovies"].value_counts()))
plt.show()

# %%
customer["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
customer["Churn"].value_counts().keys()
# Out:
# Index(['No', 'Yes'], dtype='object')

# %%
plt.bar(list(customer["Churn"].value_counts().keys()),list(customer["Churn"].value_counts()))
plt.title('Churn')
plt.show()
